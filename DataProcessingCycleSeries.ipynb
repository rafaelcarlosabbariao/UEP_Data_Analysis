# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:/Python/Machine Learning/Research/30%Success_UEP_C071018A_084_NonSlit_A_30DoD_072418_091718-01-103 (1).csv")
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Columns: 259 entries, Cycle Number to Anode Final Cut
# dtypes: float64(191), int64(1), object(67)
# memory usage: 93.2+ KB

# %%
pd.set_option('display.max_columns', None)
display(df)
# Out:
#     Cycle Number  Charge Capacity (Ah)  Discharge Capacity (Ah)  \
# 0            101             58.233342                60.000186
# 1            102             60.265953                60.000033
# 2            103             59.152600                60.000001
# 3            104             59.521142                60.000042
# 4            105             59.274204                60.000017
# 5            106             59.780636                60.000228
# 6            107             59.127281                60.000402
# 7            108             60.280252                60.000266
# 8            109             59.011839                60.000144
# 9            110             60.330079                60.000315
# 10           111             59.489204                60.000067
# 11           112             59.895022                60.000338
# 12           113             59.474443                60.000283
# 13           114             58.615489                60.000304
# ...

# %%
df.shape == df.dropna().shape # checks for missing values
# Out:
# False

# %%
X = df.iloc[:, 0].values # [row, columns]
y_1 = df.iloc[:, [1]].values # charge capacity
y_2 = df.iloc[:, [2]].values # discharge capacity
# 1, 2 --> charge, discharge capacity (Ah)
# 6, 7 --> charge, discharge energy (Wh)
# 14, 15 --> minimum, maximum potential (V)
# 31, 32 --> maximum charge, minimum discharge power (W)

y1 = plt.plot(X, y_1, color = 'red', label = 'Charge Capacity')
y2 = plt.plot(X, y_2, color = 'blue', label = 'Discharge Capacity')
plt.xlabel('Cycle Number')
plt.ylabel('Charge/Discharge Capacity (Ah)')
plt.legend(loc='lower left')

# %%
def fadecycle():
    initial_DC = df.iloc[[1], [2]].values
    for _, row in df.iloc[1:, :].iterrows(): 
        if row[2] <= 0.8 * initial_DC:
            print(row[0], row[2])

# %%
print(fadecycle())
# Out:
# 138 46.81879304
# 139 43.10925148
# 140 40.33167306
# 141 38.64781188
# 142 37.33765924
# 143 36.67580096
# 144 34.37053032
# 145 32.73379815
# 146 0.0
# None
